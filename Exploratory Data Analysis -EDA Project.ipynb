# %% [markdown]
# <center> <h3>Exploratory Data Analysis-EDA <h3> </center>

# %% [markdown]
# ** Let us first Import Required libraries and Data File**

# %%
#write code here
import pandas as pd
import seaborn as sns
import numpy as np
sns.set()
# %matplotlib inline

# %% [markdown]
#  #Read Fifa.csv file

# %%
#Read Fifa.csv file
df1=pd.read_csv("fifa.csv")
df1.head()
df1.columns
# Out:
# Index(['id', ' name', ' rating', ' position', ' height', ' foot', ' rare',
#        ' pace', ' shooting', ' passing', ' dribbling', ' defending',
#        ' heading', ' diving', ' handling', ' kicking', ' reflexes', ' speed',
#        ' positioning'],
#       dtype='object')

# %% [markdown]
#  #Copy dataframe in df

# %%
#Copy dataframe in df
df=df1.copy()

# %%
#Display the first five rows of the dataframe
df1.head()
# Out:
#        id                     name   rating  position   height    foot   rare  \
# 0    1001             Gábor Király       69        GK      191   Right      0
# 1  100143             Frederik Boi       65         M      184   Right      0
# 2  100264          Tomasz Szewczuk       57         A      185   Right      0
# 3  100325   Steeve Joseph-Reinette       63         D      180    Left      0
# 4  100326             Kamel Chafni       72         M      181   Right      0
#
#    pace  shooting  passing  dribbling  defending  heading  diving  handling  \
# 0                                                              70        66
# 1    61        65       63         59         62       62
# 2    65        54       43         53         55       74
# 3    68        38       51         46         64       71
# 4    75        64       67         72         57       66
#
#    kicking  reflexes  speed   positioning
# 0       63        74     35          66.0
# ...

# %%
# Display columns names of the dataframe
df1.columns
# Out:
# Index(['id', ' name', ' rating', ' position', ' height', ' foot', ' rare',
#        ' pace', ' shooting', ' passing', ' dribbling', ' defending',
#        ' heading', ' diving', ' handling', ' kicking', ' reflexes', ' speed',
#        ' positioning'],
#       dtype='object')

# %%
#Remove extra space in column names
df1.columns=df1.columns.str.replace(" ","")
df1.columns
# Out:
# Index(['id', 'name', 'rating', 'position', 'height', 'foot', 'rare', 'pace',
#        'shooting', 'passing', 'dribbling', 'defending', 'heading', 'diving',
#        'handling', 'kicking', 'reflexes', 'speed', 'positioning'],
#       dtype='object')

# %%
#Check data type of columns
type(df1.columns)
df1.dtypes
# Out:
# id               int64
# name            object
# rating           int64
# position        object
# height           int64
# foot            object
# rare             int64
# pace            object
# shooting        object
# passing         object
# dribbling       object
# defending       object
# heading         object
# diving          object
# handling        object
# kicking         object
# reflexes        object
# speed           object
# positioning    float64
# dtype: object

# %%
#Get the Last five rows of dataframe
df1.tail()
# Out:
#         id              name  rating position  height    foot  rare pace  \
# 8842  9801   Danijel Ljuboja      73        A     189    Left     1   62
# 8843  9805     Craig Bellamy      79        A     175   Right     0   80
# 8844  9807     Michel Breuer      68        D     183   Right     0   61
# 8845  9815       Gill Swerts      65        D     179   Right     0   65
# 8846  9913       Mehdi Nafti      69        M     179   Right     0   55
#
#      shooting passing dribbling defending heading diving handling kicking  \
# 8842       73      64        74        56      68    NaN      NaN     NaN
# 8843       78      67        81        62      71    NaN      NaN     NaN
# 8844       40      56        51        70      74    NaN      NaN     NaN
# 8845       48      63        65        67      69    NaN      NaN     NaN
# 8846       56      64        65        69      60    NaN      NaN     NaN
#
#      reflexes speed  positioning
# 8842      NaN   NaN          NaN
# ...

# %% [markdown]
# ### Data understanding

# %% [markdown]
# In the beginning for columns ratings and height, we see the zero skewnsess as mean and median are very much closer. But as we move t the extreme right, the trend tends to be more negetively skewed reason being the mean value<median for columns ( pace,shooting,passing upto heading)

# %%
#Get the statistical summary for the numerical columns
df1.describe()
# Out:
#                   id       rating       height         rare   positioning
# count    8847.000000  8847.000000  8847.000000  8847.000000    930.000000
# mean   152337.538035    66.680457   181.750424     0.353114     64.955914
# std     54506.606056     7.146679     6.454356     0.477965      8.854231
# min         2.000000    40.000000   158.000000     0.000000     37.000000
# 25%    140001.500000    62.000000   178.000000     0.000000     59.000000
# 50%    171578.000000    66.000000   182.000000     0.000000     65.000000
# 75%    189185.000000    72.000000   186.000000     1.000000     71.000000
# max    205583.000000    94.000000   208.000000     1.000000     91.000000

# %%
#Show the statistical summary of object type columns in dataframe
df1.describe(include=["O"])
# Out:
#                 name  position    foot  pace  shooting  passing  dribbling  \
# count           8847      8847    8847  8847      8847     8847       8847
# unique          8678         4       2    73        80       76         76
# top      Júlio César         M   Right
# freq               5      3041    6762   930       930      930        930
#
#         defending  heading  diving  handling  kicking  reflexes  speed
# count        8847     8847    8847      8847     8847      8847   8847
# unique         64       67      49        45       53        53     54
# top
# freq          930      930    7917      7917     7917      7917   7917

# %%
#Show the statistical summary of all the columns in dataframe**
df1.describe(include="all")
# Out:
#                    id     name       rating position       height    foot  \
# count     8847.000000     8847  8847.000000     8847  8847.000000    8847
# unique            NaN     8678          NaN        4          NaN       2
# top               NaN   Felipe          NaN        M          NaN   Right
# freq              NaN        5          NaN     3041          NaN    6762
# mean    152337.538035      NaN    66.680457      NaN   181.750424     NaN
# std      54506.606056      NaN     7.146679      NaN     6.454356     NaN
# min          2.000000      NaN    40.000000      NaN   158.000000     NaN
# 25%     140001.500000      NaN    62.000000      NaN   178.000000     NaN
# 50%     171578.000000      NaN    66.000000      NaN   182.000000     NaN
# 75%     189185.000000      NaN    72.000000      NaN   186.000000     NaN
# max     205583.000000      NaN    94.000000      NaN   208.000000     NaN
#
#                rare  pace shooting passing dribbling defending heading diving  \
# ...

# %%
#Count the number of missing values in each column
df1.isnull().sum()
# Out:
# id                0
# name              0
# rating            0
# position          0
# height            0
# foot              0
# rare              0
# pace            930
# shooting        930
# passing         930
# dribbling       930
# defending       930
# heading         930
# diving         7917
# handling       7917
# kicking        7917
# reflexes       7917
# speed          7917
# positioning    7917
# dtype: int64

# %%
#Replace extra space with NaN
df1=df1.replace(" ",np.nan)
df1.isnull().sum()
# Out:
# id                0
# name              0
# rating            0
# position          0
# height            0
# foot              0
# rare              0
# pace            930
# shooting        930
# passing         930
# dribbling       930
# defending       930
# heading         930
# diving         7917
# handling       7917
# kicking        7917
# reflexes       7917
# speed          7917
# positioning    7917
# dtype: int64

# %%
#Fill all null values of dataframe with 0
df1=df1.fillna(0)

# %%
#write code here
df1.isnull().sum()
# Out:
# id             0
# name           0
# rating         0
# position       0
# height         0
# foot           0
# rare           0
# pace           0
# shooting       0
# passing        0
# dribbling      0
# defending      0
# heading        0
# diving         0
# handling       0
# kicking        0
# reflexes       0
# speed          0
# positioning    0
# dtype: int64

# %%
#Check datatypes of all columns
df1.dtypes
# Out:
# id               int64
# name            object
# rating           int64
# position        object
# height           int64
# foot            object
# rare             int64
# pace            object
# shooting        object
# passing         object
# dribbling       object
# defending       object
# heading         object
# diving          object
# handling        object
# kicking         object
# reflexes        object
# speed           object
# positioning    float64
# dtype: object

# %%
#Type casting to int data type
mylist=['pace','shooting', 'passing', 'dribbling', 'defending', 'heading', 'diving',
       'handling', 'kicking', 'reflexes', 'speed', 'positioning']
df1[mylist]=df1[mylist].astype('int')
df1.dtypes
# Out:
# id              int64
# name           object
# rating          int64
# position       object
# height          int64
# foot           object
# rare            int64
# pace            int32
# shooting        int32
# passing         int32
# dribbling       int32
# defending       int32
# heading         int32
# diving          int32
# handling        int32
# kicking         int32
# reflexes        int32
# speed           int32
# positioning     int32
# dtype: object

# %%
#spliting the dataframe based on positions
df_goalkeeper= df1[df1['position'] == 'GK']
df_goalkeeper
# Out:
# Empty DataFrame
# Columns: [id, name, rating, position, height, foot, rare, pace, shooting, passing, dribbling, defending, heading, diving, handling, kicking, reflexes, speed, positioning]
# Index: []

# %%
# checking the Unique positions
df1["position"].unique()
# Out:
# array([' GK', ' M', ' A', ' D'], dtype=object)

# %%
#Remove extra space in position column and remove it like ' GK' to 'GK' and then again make dataframe of GK**<br>

df1["position"]=df1["position"].str.replace(" ","")
df1["position"].unique()
# Out:
# array(['GK', 'M', 'A', 'D'], dtype=object)

# %%
#make a dataframe of df_goalkeeper
df_goalkeeper=pd.DataFrame()
df_goalkeeper
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Drop the columns
gk=['pace','shooting','passing','dribbling','defending','heading']
df_goalkeeper=df1[df1.columns.drop(gk)]
df_goalkeeper
# Out:
#           id                     name  rating position  height    foot  rare  \
# 0       1001             Gábor Király      69       GK     191   Right     0
# 1     100143             Frederik Boi      65        M     184   Right     0
# 2     100264          Tomasz Szewczuk      57        A     185   Right     0
# 3     100325   Steeve Joseph-Reinette      63        D     180    Left     0
# 4     100326             Kamel Chafni      72        M     181   Right     0
# ...      ...                      ...     ...      ...     ...     ...   ...
# 8842    9801          Danijel Ljuboja      73        A     189    Left     1
# 8843    9805            Craig Bellamy      79        A     175   Right     0
# 8844    9807            Michel Breuer      68        D     183   Right     0
# 8845    9815              Gill Swerts      65        D     179   Right     0
# 8846    9913              Mehdi Nafti      69        M     179   Right     0
#
# ...

# %%
#Make the dataframe of df_players having data of the all the other players except the goal keeper

df_players=pd.DataFrame()

# %% [markdown]
# **vi. Dataframe of other players must contain the following columns 'id', 'name', 'rating', 'position', 'height', 'foot', 'rare',  'pace', 'shooting', 'passing', 'dribbling', 'defending', 'heading'** <br>
# **Drop all the other columns**

# %%
#write code here
drp=['diving','handling','kicking','reflexes','speed','positioning']
df_players=df1[df1.columns.drop(drp)]

# %%
#write code here
df_players.head()
# Out:
#        id                     name  rating position  height    foot  rare  \
# 0    1001             Gábor Király      69       GK     191   Right     0
# 1  100143             Frederik Boi      65        M     184   Right     0
# 2  100264          Tomasz Szewczuk      57        A     185   Right     0
# 3  100325   Steeve Joseph-Reinette      63        D     180    Left     0
# 4  100326             Kamel Chafni      72        M     181   Right     0
#
#    pace  shooting  passing  dribbling  defending  heading
# 0     0         0        0          0          0        0
# 1    61        65       63         59         62       62
# 2    65        54       43         53         55       74
# 3    68        38       51         46         64       71
# 4    75        64       67         72         57       66

# %%
#Find shape of both the datasets
df_goalkeeper.shape
# Out:
# (8847, 13)

# %%
#write code here
df_players.shape
# Out:
# (8847, 13)

# %%
#Check head of both the splited dataframe
df_goalkeeper.head()
# Out:
#        id                     name  rating position  height    foot  rare  \
# 0    1001             Gábor Király      69       GK     191   Right     0
# 1  100143             Frederik Boi      65        M     184   Right     0
# 2  100264          Tomasz Szewczuk      57        A     185   Right     0
# 3  100325   Steeve Joseph-Reinette      63        D     180    Left     0
# 4  100326             Kamel Chafni      72        M     181   Right     0
#
#    diving  handling  kicking  reflexes  speed  positioning
# 0      70        66       63        74     35           66
# 1       0         0        0         0      0            0
# 2       0         0        0         0      0            0
# 3       0         0        0         0      0            0
# 4       0         0        0         0      0            0

# %%
#Write Your Code Here
df_players.head()
# Out:
#        id                     name  rating position  height    foot  rare  \
# 0    1001             Gábor Király      69       GK     191   Right     0
# 1  100143             Frederik Boi      65        M     184   Right     0
# 2  100264          Tomasz Szewczuk      57        A     185   Right     0
# 3  100325   Steeve Joseph-Reinette      63        D     180    Left     0
# 4  100326             Kamel Chafni      72        M     181   Right     0
#
#    pace  shooting  passing  dribbling  defending  heading
# 0     0         0        0          0          0        0
# 1    61        65       63         59         62       62
# 2    65        54       43         53         55       74
# 3    68        38       51         46         64       71
# 4    75        64       67         72         57       66

# %%
# summary stats of goal keeper
df_goalkeeper.describe()
# Out:
#                   id       rating       height         rare       diving  \
# count    8847.000000  8847.000000  8847.000000  8847.000000  8847.000000
# mean   152337.538035    66.680457   181.750424     0.353114     7.080027
# std     54506.606056     7.146679     6.454356     0.477965    20.833316
# min         2.000000    40.000000   158.000000     0.000000     0.000000
# 25%    140001.500000    62.000000   178.000000     0.000000     0.000000
# 50%    171578.000000    66.000000   182.000000     0.000000     0.000000
# 75%    189185.000000    72.000000   186.000000     1.000000     0.000000
# max    205583.000000    94.000000   208.000000     1.000000    91.000000
#
#           handling      kicking     reflexes        speed  positioning
# count  8847.000000  8847.000000  8847.000000  8847.000000  8847.000000
# mean      6.805471     6.629705     7.239177     5.068159     6.828190
# std      20.028998    19.546697    21.303662    15.162321    20.129214
# ...

# %% [markdown]
# Rating and height columns make the dataset zero skewed as the mean and median are pretty much closer. Apart from this, there is no significant peiece of information we can achieve.

# %%
# summary stats of players
df_players.describe()
# Out:
#                   id       rating       height         rare         pace  \
# count    8847.000000  8847.000000  8847.000000  8847.000000  8847.000000
# mean   152337.538035    66.680457   181.750424     0.353114    60.792811
# std     54506.606056     7.146679     6.454356     0.477965    23.362877
# min         2.000000    40.000000   158.000000     0.000000     0.000000
# 25%    140001.500000    62.000000   178.000000     0.000000    57.000000
# 50%    171578.000000    66.000000   182.000000     0.000000    67.000000
# 75%    189185.000000    72.000000   186.000000     1.000000    75.000000
# max    205583.000000    94.000000   208.000000     1.000000    96.000000
#
#           shooting      passing    dribbling    defending      heading
# count  8847.000000  8847.000000  8847.000000  8847.000000  8847.000000
# mean     49.267096    52.659659    54.761162    53.996609    57.042613
# std      20.966021    20.816230    22.061386    21.059882    21.318433
# ...

# %% [markdown]
# ### summary statistics of other players?

# %% [markdown]
# In the beginning for columns ratings and height, we see the zero skewnsess as mean and median are very much closer. But as we move t the extreme right, the trend tends to be more negetively skewed reason being the mean value<median for columns ( pace,shooting,passing upto heading)

# %% [markdown]
# Display averages of each columns according the players' positions**

# %%
tlist=['rating','position','height','foot','rare','pace','shooting','passing','dribbling','defending','heading','diving','handling','kicking','reflexes','speed','positioning']
df1.groupby('position')[tlist].mean()
# Out:
#              rating      height      rare       pace   shooting    passing  \
# position
# A         67.260807  180.938521  0.475024  72.488473  63.759846  54.357349
# D         66.059055  183.145669  0.270938  63.930923  43.618110  55.465283
# GK        65.918280  188.233333  0.345161   0.000000   0.000000   0.000000
# M         67.087142  179.041763  0.347583  68.493916  59.601776  65.024005
#
#           dribbling  defending    heading     diving   handling    kicking  \
# position
# A         66.664265  50.905860  64.756484   0.000000   0.000000   0.000000
# D         51.836793  68.069435  66.837867   0.000000   0.000000   0.000000
# GK         0.000000   0.000000   0.000000  67.351613  64.739785  63.067742
# M         66.045709  59.696153  60.206511   0.000000   0.000000   0.000000
#
#            reflexes      speed  positioning
# position
# A          0.000000   0.000000     0.000000
# D          0.000000   0.000000     0.000000
# GK        68.865591  48.212903    64.955914
# ...

# %%
##Count number of players against each position and foot used by them    

df1.groupby('position')['foot'].count()
# Out:
# position
# A     2082
# D     2794
# GK     930
# M     3041
# Name: foot, dtype: int64

# %%
# Let us Perform grouping on position and foot to find mean, min and max values of rating. We will Store the result in a variable called 'a'
a=df1.agg({"position":["mean",'min','max'],'foot':["mean",'min','max'],'rating':['mean','min','max']})
a
# Out:
#      position    foot     rating
# max         M   Right  94.000000
# mean      NaN     NaN  66.680457
# min         A    Left  40.000000

# %%
table = pd.pivot_table(df1,index = 'position',columns = 'foot',values='rating',aggfunc=['min','mean'])
table
# Out:
#            min              mean
# foot      Left  Right       Left      Right
# position
# A           51     41  67.758152  67.154026
# D           47     42  65.931148  66.121341
# GK          52     40  68.102041  65.661058
# M           43     41  67.778409  66.878905

# %% [markdown]
# Data Visualization

# %% [markdown]
# ###  Display total players of each position.

# %%
sns.countplot(data=df1,x="position")

# %% [markdown]
# The countplot shows the highest count for midfielder and then defender and lowest count for the goalkeeper (GK) position that makes sense because goalkeeper count should be less than other players.

# %% [markdown]
# ###  Show the total number of players for each foot type.

# %%
sns.countplot(data=df1,x="foot")

# %% [markdown]
# ###  'foot' ditribution per 'rating' using boxplot

# %%
ax = sns.boxplot(x="rating", y="foot",data=df1)

# %% [markdown]
# We can see outliers in case of right food in which the rating is also low(40-50) but there are some more outliers for postive rating as well.In case of left foot more data is centered around the mean value with less number od outliers comparad to the right foot.

# %% [markdown]
# ### Display total number of players for each foot type according to their positions. But the result of each position should be a separate graph yet shown collectively  <br>

# %%
df1.head()
df_M=df1[df1['position']=='M']
df_M.head()
df_GK=df1[df1['position']=='GK']
df_GK
df_A=df1[df1['position']=='A']
df_D=df1[df1['position']=='D']
df_D
# Out:
#           id                     name  rating position  height    foot  rare  \
# 3     100325   Steeve Joseph-Reinette      63        D     180    Left     0
# 5     100329           Abdoulaye Faye      72        D     187   Right     1
# 16    100670          Ashley Westwood      54        D     183   Right     0
# 18    100707             David Artell      59        D     188   Right     0
# 21    100751           Kevin O'Connor      59        D     180   Right     0
# ...      ...                      ...     ...      ...     ...     ...   ...
# 8823    8842           Lionel Scaloni      68        D     182   Right     0
# 8825     887            Nathan Clarke      62        D     185   Right     0
# 8835    9639               Aitor Ocio      72        D     187   Right     0
# 8844    9807            Michel Breuer      68        D     183   Right     0
# 8845    9815              Gill Swerts      65        D     179   Right     0
#
# ...

# %%
# Write the code to find the correlation here
from matplotlib import pyplot as plt
fig, ax=plt.subplots(2,2,sharey=True, figsize=(15,8))
sns.countplot(x='foot', data=df_M, ax=ax[0,0])
sns.countplot(x='foot', data=df_GK, ax=ax[0,1])
sns.countplot(x='foot', data=df_A, ax=ax[1,0])
sns.countplot(x='foot', data=df_D, ax=ax[1,1])

# %%
df1['position'].unique()
df1['position']
# Out:
# 0       GK
# 1        M
# 2        A
# 3        D
# 4        M
#         ..
# 8842     A
# 8843     A
# 8844     D
# 8845     D
# 8846     M
# Name: position, Length: 8847, dtype: object

# %% [markdown]
# ###  Relationship/correlation  ratings and defending of other players.<br>

# %%
#Write code here
x = sns.regplot(x="rating", y="defending", data=df1)

# %% [markdown]
# A positive correlation among the rating and defending of other players. Maximum data is centered  between the 60 to 80 value against dfending values between 25 to 80.

# %% [markdown]
# ###  Plot a graph to show the relationship/correlation among rating and handling of goal keeper. Also the distributions of each should be displayed along with the graph showing the relationship.<br>

# %%
df_goalkeeper.head()
sns.jointplot(data=df_goalkeeper, x="rating", y="handling")

# %% [markdown]
# ### We will make a heatmap to show correlation among all the columns of the goal keeper dataframe and answer the questions

# %%
# find the correlation
corr = df_GK.corr()

# %%
#write code here for heatmap
corr.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# C:\Users\user\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# C:\Users\user\Anaconda3\lib\site-packages\pandas\io\formats\style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_d10f9c52_79f6_11ec_a1ef_34e6d72bd0c6row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d10f9c52_79f6_11ec_a1ef_34e6d72bd0c6row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d10f9c52_79f6_11ec_a1ef_34e6d72bd0c6row0_col2 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# **Question: Which columns/variables/factors are important to determine ratings of goal keepers and why?**
#
#
# The rating column has positive correlation(close to 1) with columns including diving,handling,positioning,and reflexes. So they are important to determine the rating of GK.

# %%
correlation=df1.corr()

# %%
#write code here for heatmap
correlation.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_e2195898_79f6_11ec_9451_34e6d72bd0c6row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_e2195898_79f6_11ec_9451_34e6d72bd0c6row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e2195898_79f6_11ec_9451_34e6d72bd0c6row0_col2 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_e2195898_79f6_11ec_9451_34e6d72bd0c6row0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_e2195898_79f6_11ec_9451_34e6d72bd0c6row0_col4 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_e2195898_79f6_11ec_9451_34e6d72bd0c6row0_col5 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_e2195898_79f6_11ec_9451_34e6d72bd0c6row0_col6 {
#             background-color:  #cdd9ec;
#             color:  #000000;
# ...

# %%
# count of rare players in each type of postion?
df1.groupby('position')['rare'].count()
# Out:
# position
# A     2082
# D     2794
# GK     930
# M     3041
# Name: rare, dtype: int64
